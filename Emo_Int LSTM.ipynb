# %%
import numpy as np
import pandas as pd
import math

# %%
# Training data
anger_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_train.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])

# %%
anger_train.head(3)
# Out:
#    index                                              tweet Emotion  score
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger  0.938
# 1  10001  So my Indian Uber driver just called someone t...   anger  0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger  0.896

# %%
# Validation data
anger_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])


anger_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
anger_dev.reset_index(drop=False, inplace=True)
anger_dev.drop('score', axis=1, inplace=True)

fear_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
fear_dev.reset_index(drop=False, inplace=True)
fear_dev.drop('score', axis=1, inplace=True)

joy_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
joy_dev.reset_index(drop=False, inplace=True)
joy_dev.drop('score', axis=1, inplace=True)

sadness_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
sadness_dev.reset_index(drop=False, inplace=True)
sadness_dev.drop('score', axis=1, inplace=True)

# %%
anger_dev_with_intensity.head(3)
# Out:
#    index                                              tweet Emotion  score
# 0  10941  At the point today where if someone says somet...   anger  0.319
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger  0.144
# 2  10943  This game has pissed me off more than any othe...   anger  0.898

# %%
anger_dev.head(3)
# Out:
#    index                                              tweet Emotion
# 0  10857  @ZubairSabirPTI  pls dont insult the word 'Molna'   anger
# 1  10858  @ArcticFantasy I would have almost took offens...   anger
# 2  10859  @IllinoisLoyalty that Rutgers game was an abom...   anger

# %%
# Test data
anger_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])


anger_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_test.txt',  sep='\t', names=['index', 'tweet', 'Emotion','score'])
anger_test.drop('score', axis=1, inplace=True)

fear_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_test.txt',  sep='\t', names=['index', 'tweet', 'Emotion','score'])
fear_test.drop('score', axis=1, inplace=True)

joy_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_test.txt',  sep='\t', names=['index', 'tweet', 'Emotion','score'])
joy_test.drop('score', axis=1, inplace=True)

sadness_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_test.txt',  sep='\t', names=['index','tweet', 'Emotion','score'])
sadness_test.drop('score', axis=1, inplace=True)

# %%
anger_test_with_intensity.head(3)
# Out:
#    index                                              tweet Emotion  score
# 0  10941  At the point today where if someone says somet...   anger  0.319
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger  0.144
# 2  10943  This game has pissed me off more than any othe...   anger  0.898

# %%
anger_test.head(3)
# Out:
#    index                                              tweet Emotion
# 0  10941  At the point today where if someone says somet...   anger
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger
# 2  10943  This game has pissed me off more than any othe...   anger

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    tokens = word_tokenize(text)
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
    return ' '.join(filtered_tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
anger_train['tweet'] = anger_train['tweet'].apply(preprocess_text)
fear_train['tweet'] = fear_train['tweet'].apply(preprocess_text)
joy_train['tweet'] = joy_train['tweet'].apply(preprocess_text)
sadness_train['tweet'] = sadness_train['tweet'].apply(preprocess_text)


anger_dev_with_intensity['tweet'] = anger_dev_with_intensity['tweet'].apply(preprocess_text)
fear_dev_with_intensity['tweet'] = fear_dev_with_intensity['tweet'].apply(preprocess_text)
joy_dev_with_intensity['tweet'] = joy_dev_with_intensity['tweet'].apply(preprocess_text)
sadness_dev_with_intensity['tweet'] = sadness_dev_with_intensity['tweet'].apply(preprocess_text)

anger_dev['tweet'] = anger_dev['tweet'].apply(preprocess_text)
fear_dev['tweet'] = fear_dev['tweet'].apply(preprocess_text)
joy_dev['tweet'] = joy_dev['tweet'].apply(preprocess_text)
sadness_dev['tweet'] = sadness_dev['tweet'].apply(preprocess_text)


anger_test_with_intensity['tweet'] = anger_test_with_intensity['tweet'].apply(preprocess_text)
fear_test_with_intensity['tweet'] = fear_test_with_intensity['tweet'].apply(preprocess_text)
joy_test_with_intensity['tweet'] = joy_test_with_intensity['tweet'].apply(preprocess_text)
sadness_test_with_intensity['tweet'] = sadness_test_with_intensity['tweet'].apply(preprocess_text)

anger_test['tweet'] = anger_test['tweet'].apply(preprocess_text)
fear_test['tweet'] = fear_test['tweet'].apply(preprocess_text)
joy_test['tweet'] = joy_test['tweet'].apply(preprocess_text)
sadness_test['tweet'] = sadness_test['tweet'].apply(preprocess_text)

# %%
anger_train['tweet'][1]
# Out:
# 'indian uber driver called someone n word wasnt moving vehicle id jumped disgusted'

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding, SpatialDropout1D
from keras.callbacks import EarlyStopping

# %%
emotions = ['anger', 'fear', 'joy', 'sadness']
X_train_all = []
y_train_all = []
X_val_all = []
y_val_all = []
X_test_all=[]
y_test_all=[]

for emotion in emotions:
    X_train = globals()[f"{emotion}_train"]['tweet']
    y_train = globals()[f"{emotion}_train"]['score']
    X_val = globals()[f"{emotion}_dev_with_intensity"]['tweet']
    y_val = globals()[f"{emotion}_dev_with_intensity"]['score']
    X_test = globals()[f"{emotion}_test_with_intensity"]['tweet']
    y_test = globals()[f"{emotion}_test_with_intensity"]['score']

    X_train_all.extend(X_train)
    y_train_all.extend(y_train)
    X_val_all.extend(X_val)
    y_val_all.extend(y_val)
    X_test_all.extend(X_train)
    y_test_all.extend(y_train)

# %%
# Tokenize the text data
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train_all)

X_train_seq = tokenizer.texts_to_sequences(X_train_all)
X_val_seq = tokenizer.texts_to_sequences(X_val_all)
X_test_seq = tokenizer.texts_to_sequences(X_test_all)

# Pad sequences
max_len = max([len(seq) for seq in X_train_seq])
X_train_padded = pad_sequences(X_train_seq, maxlen=max_len, padding='post')
X_val_padded = pad_sequences(X_val_seq, maxlen=max_len, padding='post')
X_test_padded = pad_sequences(X_test_seq, maxlen=max_len, padding='post')

# Convert scores to arrays
y_train_arr = np.array(y_train_all)
y_val_arr = np.array(y_val_all)
y_test_arr = np.array(y_test_all)

# %%
tokenizer.word_index
# Out:
# {'im': 1,
#  'like': 2,
#  'dont': 3,
#  'get': 4,
#  'amp': 5,
#  'one': 6,
#  'people': 7,
#  'time': 8,
#  'day': 9,
#  'know': 10,
#  'good': 11,
#  'love': 12,
#  'u': 13,
#  'cant': 14,
#  'think': 15,
#  'lively': 16,
#  'watch': 17,
#  'still': 18,
#  'would': 19,
#  'got': 20,
#  'go': 21,
#  'make': 22,
#  'today': 23,
#  'happy': 24,
#  'want': 25,
#  'never': 26,
#  'lost': 27,
#  'see': 28,
#  'back': 29,
#  'really': 30,
#  'life': 31,
#  'feel': 32,
#  'always': 33,
#  'need': 34,
#  'way': 35,
#  'amazing': 36,
#  'going': 37,
#  'even': 38,
#  'much': 39,
#  'start': 40,
#  'someone': 41,
#  'work': 42,
#  'right': 43,
#  'na': 44,
#  'sad': 45,
#  'new': 46,
#  'fear': 47,
#  '2': 48,
#  'youre': 49,
#  'ever': 50,
#  'lol': 51,
#  'ive': 52,
#  'anger': 53,
#  'man': 54,
#  'smile': 55,
#  'broadcast': 56,
#  'musically': 57,
#  'us': 58,
#  'first': 59,
#  'angry': 60,
#  'let': 61,
#  'bad': 62,
#  'give': 63,
#  'terrible': 64,
#  'terrorism': 65,
# ...

# %%
max_len
# Out:
# 19

# %%
X_train_padded.shape
# Out:
# (3613, 19)

# %%
X_val_padded.shape
# Out:
# (1908, 19)

# %%
y_train_arr.shape
# Out:
# (3613,)

# %%
y_val_arr.shape
# Out:
# (1908,)

# %%
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='linear'))

model.compile(loss='mean_squared_error', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 19, 100)           1042800
#
#  spatial_dropout1d_1 (Spati  (None, 19, 100)           0
#  alDropout1D)
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense_1 (Dense)             (None, 1)                 101
#
# ...
# Total params: 1123301 (4.29 MB)
# Trainable params: 1123301 (4.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train_padded, y_train_arr, epochs=10, batch_size=32, validation_data=(X_val_padded, y_val_arr))
# Out:
# Epoch 1/10
# 113/113 [==============================] - 5s 47ms/step - loss: 0.0112 - val_loss: 0.0329
# Epoch 2/10
# 113/113 [==============================] - 7s 60ms/step - loss: 0.0097 - val_loss: 0.0307
# Epoch 3/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0087 - val_loss: 0.0317
# Epoch 4/10
# 113/113 [==============================] - 7s 59ms/step - loss: 0.0082 - val_loss: 0.0358
# Epoch 5/10
# 113/113 [==============================] - 5s 45ms/step - loss: 0.0073 - val_loss: 0.0318
# Epoch 6/10
# 113/113 [==============================] - 6s 51ms/step - loss: 0.0065 - val_loss: 0.0358
# Epoch 7/10
# 113/113 [==============================] - 6s 54ms/step - loss: 0.0063 - val_loss: 0.0359
# Epoch 8/10
# 113/113 [==============================] - 5s 46ms/step - loss: 0.0056 - val_loss: 0.0368
# Epoch 9/10
# 113/113 [==============================] - 7s 58ms/step - loss: 0.0053 - val_loss: 0.0338
# Epoch 10/10
# ...

# %%
val_loss = model.evaluate(X_val_padded, y_val_arr)
print(f"Validation Loss: {val_loss}")
# Out:
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0321
# Validation Loss: 0.032138217240571976

# %%
result = model.evaluate(X_test_padded, y_test_arr)
print(f"Test Loss: {result}")
# Out:
# 113/113 [==============================] - 1s 10ms/step - loss: 0.0042
# Test Loss: 0.004168604034930468

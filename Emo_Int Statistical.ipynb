# %%
import numpy as np
import pandas as pd
import math

# %% [markdown]
# **Data Preprocessing**

# %%
# Training data
anger_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_train.txt', sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_train = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_train.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])

# %%
anger_train.head(3)
# Out:
#    index                                              tweet Emotion  score
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger  0.938
# 1  10001  So my Indian Uber driver just called someone t...   anger  0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger  0.896

# %%
# Validation data
anger_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_dev_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_dev_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])


anger_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
anger_dev.reset_index(drop=False, inplace=True)
anger_dev.drop('score', axis=1, inplace=True)

fear_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
fear_dev.reset_index(drop=False, inplace=True)
fear_dev.drop('score', axis=1, inplace=True)

joy_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
joy_dev.reset_index(drop=False, inplace=True)
joy_dev.drop('score', axis=1, inplace=True)

sadness_dev = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_dev.txt',  sep='\t', names=['tweet', 'Emotion','score'])
sadness_dev.reset_index(drop=False, inplace=True)
sadness_dev.drop('score', axis=1, inplace=True)

# %%
anger_dev_with_intensity.head(3)
# Out:
#    index                                              tweet Emotion  score
# 0  10941  At the point today where if someone says somet...   anger  0.319
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger  0.144
# 2  10943  This game has pissed me off more than any othe...   anger  0.898

# %%
anger_dev.head(3)
# Out:
#    index                                              tweet Emotion
# 0  10857  @ZubairSabirPTI  pls dont insult the word 'Molna'   anger
# 1  10858  @ArcticFantasy I would have almost took offens...   anger
# 2  10859  @IllinoisLoyalty that Rutgers game was an abom...   anger

# %%
# Test data
anger_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
fear_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
joy_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])
sadness_test_with_intensity = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_test_w.txt',  sep='\t', names=['index', 'tweet', 'Emotion', 'score'])


anger_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/anger_test.txt',  sep='\t', names=['index', 'tweet', 'Emotion','score'])
anger_test.drop('score', axis=1, inplace=True)

fear_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/fear_test.txt',  sep='\t', names=['index', 'tweet', 'Emotion','score'])
fear_test.drop('score', axis=1, inplace=True)

joy_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/joy_test.txt',  sep='\t', names=['index', 'tweet', 'Emotion','score'])
joy_test.drop('score', axis=1, inplace=True)

sadness_test = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/sadness_test.txt',  sep='\t', names=['index','tweet', 'Emotion','score'])
sadness_test.drop('score', axis=1, inplace=True)

# %%
anger_test_with_intensity.head(3)
# Out:
#    index                                              tweet Emotion  score
# 0  10941  At the point today where if someone says somet...   anger  0.319
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger  0.144
# 2  10943  This game has pissed me off more than any othe...   anger  0.898

# %%
anger_test.head(3)
# Out:
#    index                                              tweet Emotion
# 0  10941  At the point today where if someone says somet...   anger
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger
# 2  10943  This game has pissed me off more than any othe...   anger

# %%
all_train_data = pd.concat([anger_train, fear_train, joy_train, sadness_train], ignore_index=True)

all_dev_data = pd.concat([anger_dev, fear_dev, joy_dev, sadness_dev], ignore_index=True)

all_test_data = pd.concat([anger_test, fear_test, joy_test, sadness_test], ignore_index=True)

all_test_data_with_intensity = pd.concat([anger_test_with_intensity, fear_test_with_intensity, joy_test_with_intensity, sadness_test_with_intensity], ignore_index=True)

# %%
all_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3613 entries, 0 to 3612
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    3613 non-null   int64
#  1   tweet    3613 non-null   object
#  2   Emotion  3613 non-null   object
#  3   score    3613 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 113.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(all_train_data['score'], bins=20, kde=True)
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Distribution of Score')
plt.show()

# %%
all_dev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    347 non-null    int64
#  1   tweet    347 non-null    object
#  2   Emotion  347 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 8.3+ KB

# %%
all_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142 entries, 0 to 3141
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    3142 non-null   int64
#  1   tweet    3142 non-null   object
#  2   Emotion  3142 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 73.8+ KB

# %% [markdown]
# **VADER** (Valence Aware Dictionary and sEntiment Reasoner) lexicon

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def get_vader_sentiment_score(text):
    scores = sia.polarity_scores(text)
    return scores['compound']

# %%
all_train_data['vader_score'] = all_train_data['tweet'].apply(get_vader_sentiment_score)

all_dev_data['vader_score'] = all_dev_data['tweet'].apply(get_vader_sentiment_score)

all_test_data['vader_score'] = all_test_data['tweet'].apply(get_vader_sentiment_score)

# %%
from sklearn.metrics import mean_squared_error

rmse_test = math.sqrt(mean_squared_error(all_test_data_with_intensity['score'], all_test_data['vader_score']))
print(f"Root Mean Squared Error on Test Set: {rmse_test}")
# Out:
# Root Mean Squared Error on Test Set: 0.7574514805758056

# %% [markdown]
# **Lexicon-Based Approach**

# %%
nrc_lexicon = pd.read_csv('/content/drive/MyDrive/Data Science Mk/Projects/Emotional Intensity/NRC-Emotion-Lexicon-Wordlevel-v0.92.txt',
                          sep='\t', header=None, names=['word', 'emotion', 'score'])

# %%
def assign_emotion_labels(text):
    emotions = set()
    for word in text.split():
        matches = nrc_lexicon[(nrc_lexicon['word'] == word) & (nrc_lexicon['score'] == 1)]
        if not matches.empty:
            emotions.update(matches['emotion'])
    return list(emotions)

# %%
all_train_data['emotions'] = all_train_data['tweet'].apply(assign_emotion_labels)

all_dev_data['emotions'] = all_dev_data['tweet'].apply(assign_emotion_labels)

all_test_data['emotions'] = all_test_data['tweet'].apply(assign_emotion_labels)

# %%
all_test_data.head(3)
# Out:
#    index                                              tweet Emotion  \
# 0  10941  At the point today where if someone says somet...   anger
# 1  10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...   anger
# 2  10943  This game has pissed me off more than any othe...   anger
#
#    vader_score                emotions
# 0       0.5267  [positive, joy, trust]
# 1       0.0000                      []
# 2      -0.6988                      []

# %%
all_test_data['emotions_tuple'] = all_test_data['emotions'].apply(tuple)

emotion_counts = all_test_data['emotions_tuple'].value_counts()
emotion_counts
# Out:
# ()                                                843
# (positive,)                                       122
# (anger, disgust, negative, fear, sadness)         109
# (joy, trust, surprise, positive, anticipation)    106
# (positive, joy)                                   105
#                                                  ...
# (positive, surprise, sadness)                       1
# (surprise, disgust, negative, fear, sadness)        1
# (trust, surprise, disgust, negative, fear)          1
# (surprise, negative, fear, anticipation)            1
# (positive, anticipation, sadness)                   1
# Name: emotions_tuple, Length: 332, dtype: int64

# %%
emotion_counts = all_test_data['emotions'].explode().value_counts()
emotion_counts
# Out:
# negative        1450
# positive        1285
# fear             933
# sadness          908
# anger            880
# anticipation     857
# joy              809
# trust            786
# disgust          603
# surprise         519
# Name: emotions, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
emotion_counts.plot(kind='bar')
plt.xlabel('Emotion')
plt.ylabel('Frequency')
plt.title('Emotion Distribution in Tweets')
plt.show()

# %%
joy_tweets = all_test_data[all_test_data['emotions'].apply(lambda x: 'joy' in x)]
joy_tweets[['tweet', 'emotions']]
# Out:
#                                                   tweet  \
# 0     At the point today where if someone says somet...
# 3     @spamvicious I've just found out it's Candice ...
# 7     @virginmedia I've been disconnected whilst on ...
# 8     @virginmedia I've been disconnected whilst on ...
# 9     I wanna see you smile I don't wanna see you ma...
# ...                                                 ...
# 3121  @ExaltedChampion - the jest, Kara didn't chuck...
# 3125  Boy oh boy! our weekday schedule is crazy! But...
# 3129  @Aamnaa___ @drkarthik_n your per capita income...
# 3134  Nutella is pine green forget me nots are ivory...
# 3140  I'm buying art supplies and I'm debating how s...
#
#                                                emotions
# 0                                [positive, joy, trust]
# 3                                [positive, joy, trust]
# 7      [sadness, joy, positive, negative, anticipation]
# 8      [sadness, joy, positive, negative, anticipation]
# 9     [joy, trust, surprise, positive, negative, sad...
# ...                                                 ...
# 3121           [joy, positive, negative, fear, sadness]
# 3125  [joy, trust, surprise, positive, negative, sad...
# 3129  [sadness, joy, trust, positive, negative, anti...
# 3134  [joy, trust, anticipation, positive, negative,...
# 3140   [sadness, joy, surprise, positive, anticipation]
#
# [809 rows x 2 columns]

# %%
all_test_data.columns
# Out:
# Index(['index', 'tweet', 'Emotion', 'vader_score', 'emotions',
#        'emotions_tuple'],
#       dtype='object')

# %%
def get_sentiment(emotions):
    if 'joy' in emotions or 'trust' in emotions:
        return 'Positive'
    elif 'sadness' in emotions or 'fear' in emotions or 'anger' in emotions:
        return 'Negative'
    else:
        return 'Neutral'

all_test_data['sentiment'] = all_test_data['emotions'].apply(get_sentiment)

# %%
all_test_data['emotions_tuple'] = all_test_data['emotions'].apply(tuple)


emotion_groups = all_test_data.groupby('emotions_tuple')

for emotion, group in emotion_groups:
    print(f"Emotion: {emotion}")
    print(group[['tweet', 'sentiment']])
    print()
# Out:
# Emotion: ()
#                                                   tweet sentiment
# 1     @CorningFootball  IT'S GAME DAY!!!!      T MIN...   Neutral
# 2     This game has pissed me off more than any othe...   Neutral
# 4     @moocowward @mrsajhargreaves @Melly77 @GaryBar...   Neutral
# 5     @moocowward @mrsajhargreaves @Melly77 @GaryBar...   Neutral
# 15                     I just got murdered in madden. 🤕   Neutral
# ...                                                 ...       ...
# 3131  Winner #Champion #school #lastyear #gouniversi...   Neutral
# 3133  @pottermore : I can't find my patronus, the we...   Neutral
# 3135    I was not made for this world. #empath #unhappy   Neutral
# 3136  She used to be beautiful, but she lived her li...   Neutral
# 3138  @redBus_in #unhappy with #redbus CC, when I ta...   Neutral
#
# [843 rows x 2 columns]
#
# Emotion: ('anger',)
#                                                  tweet sentiment
# 255     Yeah I'm hot nigga, they say im burning uhhhhh  Negative
# 652  Changed my clothes at work and had my pre-work...  Negative
# 653  Changed my clothes at work and had my pre-work...  Negative
# 826  @Curculiunculus @System1Politics Yep, as I poi...  Negative
#
# Emotion: ('anger', 'anticipation', 'disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 151   no offense but could troye start dming people ...  Negative
# 222   I've learned to let go of resentment for peopl...  Negative
# 1135       Why do I have such bad anxiety it's annoying  Negative
#
# Emotion: ('anger', 'anticipation', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 3038  @TelegraphNews why is this evil corrupt fuck s...  Negative
#
# Emotion: ('anger', 'anticipation', 'sadness')
#                                                   tweet sentiment
# 2686  Usually I'm not one to rush colder weather but...  Negative
#
# Emotion: ('anger', 'disgust', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 395   I've never seen fast &amp; furious Tokyo drift...  Negative
# 1076  @addy_caylen I told her I wasn't fighting her ...  Negative
# 1612  @EricNobody @ArmouredSkeptic @YouTube This shi...  Negative
#
# Emotion: ('anger', 'disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 19    The animosity toward Hillary comes from conspi...  Negative
# 35    When you want to say something so bad but can'...  Negative
# 68    I really wish my road rage wasn't so damn bad ...  Negative
# 92    And to discriminate only generates hate\nAnd w...  Negative
# 248   @loueezecee I don't know how much more of that...  Negative
# ...                                                 ...       ...
# 2922  @chrislhayes It's hard for most folks to reali...  Negative
# 2982  Grim and despair feeling-I look at self and my...  Negative
# 3006  It’s possible changing meds is best not done w...  Negative
# 3007  @seantkin @coachella @RomanDanielsXXX @kodykni...  Negative
# 3034  When I was new, I hate the Judge Judy sponsors...  Negative
#
# [109 rows x 2 columns]
#
# Emotion: ('anger', 'disgust', 'positive', 'negative', 'anticipation')
#                                                   tweet sentiment
# 202   Finally uploaded the file I needed to the univ...  Negative
# 2697  @FoxNews Very thought provoking &amp; leads on...  Negative
#
# Emotion: ('anger', 'disgust', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 195   We are raging angry.=1/2 bil $ for 2 pro Liars...  Negative
# 582   @CNNnewsroom @BrookeBCNN What can't you grasp?...  Negative
# 857   @brendancoots where's your outrage that your p...  Negative
# 1008  @peterdaou What? Hillary has 27 different cont...  Negative
#
# Emotion: ('anger', 'disgust', 'positive', 'negative', 'fear', 'anticipation')
#                                                  tweet sentiment
# 484  the world drives whoever it has assessed as te...  Negative
# 795  So going to local news immediately after #Desi...  Negative
# 796  So going to local news immediately after #Desi...  Negative
#
# Emotion: ('anger', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 146   No offense but to the ppl out there using crea...  Negative
# 490   I freaking hate working with #word on my phone...  Negative
# 491   I freaking hate working with #word on my phone...  Negative
# 751   @kylemuir17 @Ealvarezfight @danawhite @TheNoto...  Negative
# 773   @F1abraham holy shit...what the hell happened ...  Negative
# 774   @F1abraham holy shit...what the hell happened ...  Negative
# 809            I hate those sugar cookies shit is awful  Negative
# 1274  I'm sorry but since when is an #indiegames #DL...  Negative
# 1400  @TheOneSoleShoe You're doing a terrible job ex...  Negative
# 1433  I have a fear of failure but no urge to be pro...  Negative
# 1441  #2 complained then while his head and then cal...  Negative
# 1452                  That defending was awful from us!  Negative
# 1557  I had really strange and awful dreams last nig...  Negative
# 1558  I had really strange and awful dreams last nig...  Negative
# 2439  Root canal therapy has had a bad reputation in...  Negative
# 2440  Root canal therapy has had a bad reputation in...  Negative
# 2799  Shantosh: How crazy would it be to walk past a...  Negative
# 2808  Incredibly shocked and disappointed with @unit...  Negative
# 2858  Absolutely hate the Apple Watch iOS 10 update....  Negative
# 2913  But God will deliver the righteous to their pl...  Negative
# 2914  #2 complained then while his head and then cal...  Negative
#
# 254   @Susan_Wilde @oohincensed @TheCanarySays no! K...  Negative
# 711   Just saw lil homie @NICKMERCS rage on cam.  We...  Negative
# 931   I'm also upset at my incorrect use of a comma....  Negative
# 1184  #heavyheart these last couple of days, who are...  Negative
# 2651  @CNN : It's not Fox News, it's Fox Propaganda ...  Negative
# 3055  @jimmyfallon @ShawnMendes I'm just a sucker fo...  Negative
#
# Emotion: ('anger', 'negative', 'sadness', 'trust')
#                                                   tweet sentiment
# 3091  Some questions you get on Twitter make you wan...  Positive
#
# Emotion: ('anger', 'positive', 'negative')
#                                                   tweet sentiment
# 6     wanna go home and focus up on this game . Don'...  Negative
# 423                 @shod_jpg aye man she was fuming xo  Negative
# 556   @Claymakerbigsi @toghar11 @scott_mulligan_ @Bo...  Negative
# 1774  Sometimes I like to talk about my sadness.  Ot...  Negative
# 2469  My 2 teens sons just left in the car to get ha...  Negative
# 2470  My 2 teens sons just left in the car to get ha...  Negative
# 3123  @SalterUK second pair of scales I have bought ...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'anticipation')
#                                                  tweet sentiment
# 612  Look what we have available in store now!!!\n\...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'disgust')
#                                                   tweet sentiment
# 186   @Gielnorian @HedonismGaming cmode grimrail mad...  Negative
# 1894  Gen 8:21 NIV—The Lord smelled the pleasing aro...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 1598  @Patsy1207 @markheardusa @theinquisitr Do your...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1512  I'm literally never home and my parents threat...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 435   sixth form has destroyed my glowing skin im fu...  Negative
# 2530  @SentinalsMom *Baal dashed forward, boosted fo...  Negative
# 2586  When I walk in darkness of despondency, Sc.ver...  Negative
# 2824  Just because I'm hurting \nDoesn't mean I'm hu...  Negative
# 2985  @1ChiefsDan Is that pessimism or do you just w...  Negative
# 3124  I saw those dreams dashed &amp;&amp; divided l...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'joy')
#                                                   tweet sentiment
# 697   Just love Matthew Parris! Political rage is good!  Positive
# 1943  And girl I love your perfume there's something...  Positive
# 1944  And girl I love your perfume there's something...  Positive
# 2092  @_BlueCouture The hilarity of you people not r...  Positive
#
# Emotion: ('anger', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 758   Forgiving means operating with God's spirit &a...  Negative
# 2478  I believe the work I do is meaningful; my clie...  Negative
#
# Emotion: ('anger', 'positive', 'negative', 'trust')
#                                                  tweet sentiment
# 418  Glasgow Girls' is a real tonic @stratfordeast:...  Positive
# 588  Now that the n word is normalized by the media...  Positive
# 668  I swear I got anger issues but my heart big AF...  Positive
#
# Emotion: ('anger', 'surprise', 'anticipation', 'disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 160   @Who_JN I've been having a quad shot every day...  Negative
# 980   if Man U lose i may actually have a nervous br...  Negative
# 1016  @Twitch how do I stop that horror movie themed...  Negative
# 1017  @Twitch how do I stop that horror movie themed...  Negative
# 2366  Literally dying &amp; living at the same time ...  Negative
# 2367  Literally dying &amp; living at the same time ...  Negative
#
# Emotion: ('anger', 'surprise', 'anticipation', 'negative', 'fear', 'sadness')
#                                                  tweet sentiment
# 716  Can we get a shot of Lingys face at 1/4 time ?...  Negative
# 717  Can we get a shot of Lingys face at 1/4 time ?...  Negative
#
# Emotion: ('anger', 'surprise', 'disgust', 'negative', 'fear')
#                                                   tweet sentiment
# 450   @EE your website is making me feel violent rag...  Negative
# 451   @EE your website is making me feel violent rag...  Negative
# 1116  Someone set off the fire alarm and I'm so angr...  Negative
#
# Emotion: ('anger', 'surprise', 'disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 82    @EE whats with the 50p a minute charge to 150,...  Negative
# 84    Repeal/remove the 'Johnson Amendment'. It is a...  Negative
# 161   @THATSSHAWTYLO passed away early this morning ...  Negative
# 516   For every minute you are angry you lose sixty ...  Negative
# 566   @MisterAK47 it's very telling that racist bigo...  Negative
# 620   @GroovyBruce @larsrjs44 @AshvsEvilDead the 'gr...  Negative
# 643   @cameronNewton #colinkaepernick protests becau...  Negative
# 644   @cameronNewton #colinkaepernick protests becau...  Negative
# 1098                    American horror story in bed 👌🏼  Negative
# 1099          American horror story and chill tonight?😌  Negative
# 1182  @LucasDrakeH @realDonaldTrump @GenFlynn @RandP...  Negative
# 1292  @Amphabio don't kill it bees are dying at an a...  Negative
# 1307  @Cernovich It's like the horror movie The Hill...  Negative
# 1308  just looked at wood's goal again and i dont th...  Negative
# 1469  I'm so confused by the new American horror sto...  Negative
# 1514  So looks like @united would rather lose all my...  Negative
# 1541  @tcarrels  \nSo when exactly did you lose your...  Negative
# 1542  @tcarrels  \nSo when exactly did you lose your...  Negative
# 1582  Trust me to lose my wallet and have to call Li...  Negative
# 1583  Trust me to lose my wallet and have to call Li...  Negative
# 1662  @FoxNews Yeah we're also experiencing terroris...  Negative
# 1694  @torreBe Te gusta American horror story y The ...  Negative
# 2711  When you lose somebody close to your heart you...  Negative
# 2712  When you lose somebody close to your heart you...  Negative
#
# Emotion: ('anger', 'surprise', 'disgust', 'negative', 'sadness')
#                                                  tweet sentiment
# 122  Police don't wanna be called pigs but they kee...  Negative
# 211  @kjwinston11 2.  the N-word. But I think all A...  Negative
# 292  @summar_rose @turehndebushra @_taaz_mania @fxl...  Negative
# 704  He who is affected by an insult is infected by...  Negative
# 705  @RogueFatale Oh, you insult me! What, you thin...  Negative
# 706                  You insult the late Sherri Martel  Negative
#
# Emotion: ('anger', 'surprise', 'disgust', 'positive', 'negative', 'fear', 'anticipation')
#                                                  tweet sentiment
# 763  @riinkanei he's a horrible person and now i ga...  Negative
#
# Emotion: ('anger', 'surprise', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 77    I just killed a spider so big it sprayed spide...  Negative
# 121   @Yannarell @LOLGOP Despite your #outrage fatig...  Negative
# 125   I don't like pineapple I only eat them on pizz...  Negative
# 654   I just killed a spider so big it sprayed spide...  Negative
# 673   @atheist_taco @DrJillStein :^) well cucks amon...  Negative
# 1265       That rocky horror remake looks a bit w a n k  Negative
# 3054  @_iConceitedOne_  Hi! We hate that you're unha...  Negative
#
# Emotion: ('anger', 'surprise', 'disgust', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 1602  #Debates2016 #AskTrumponeQuestion why do you #...  Negative
#
# Emotion: ('anger', 'surprise', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 165   ethan was with someone in the car when he did ...  Negative
# 170   If I do my homework now I can watch revenge an...  Negative
# 396                            i'll get my revenge soon  Negative
# 690                                             revenge  Negative
# 708   @baileygazteacow NO. The gay guy and the dad r...  Negative
# 1047  @JessicaLRohlik you seriously need to pop out ...  Negative
# 1111  @AASadeq I scare people even when I'm suspende...  Negative
# 1287                           -normal people scare me*  Negative
# 1599  @andreasarahco do you actually heely on campus...  Negative
# 1675  &amp; I'll actually shoot somebody if I have t...  Negative
# 1691    @LeafyIsHere will showing off biceps scare you?  Negative
#
# Emotion: ('anger', 'surprise', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2135  what does everyone have against sparkling wate...  Negative
# 2582  @onefumi oh I see. I've seen so many people mo...  Negative
#
# Emotion: ('anger', 'surprise', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1476  @Koishiteruze she was scare not knowing what t...  Negative
#
# Emotion: ('anger', 'surprise', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 132   A black female LEO💙 was shot 8 times and died ...  Negative
# 1040  Putin feels it acceptable to bomb &amp; kill a...  Negative
# 1041  Putin feels it acceptable to bomb &amp; kill a...  Negative
#
# Emotion: ('anticipation',)
#                                                   tweet sentiment
# 107                       #Scorpio always seek revenge!   Neutral
# 110   if u have time 2 open a snap, u have time 2 re...   Neutral
# 262   @douglas_nat @one11north I need it today! Do u...   Neutral
# 263   @douglas_nat @one11north I need it today! Do u...   Neutral
# 297   #GBBO is such a homely pure piece of tv gold. ...   Neutral
# ...                                                 ...       ...
# 2984  RM will win the game at the last minutes and M...   Neutral
# 3045  Honestly today I just felt like maybe track is...   Neutral
# 3046  Honestly today I just felt like maybe track is...   Neutral
# 3089  Does she really need to pout all the time - ge...   Neutral
# 3122  Sometimes the support network is causing the d...   Neutral
#
# [65 rows x 2 columns]
#
# Emotion: ('anticipation', 'sadness')
#                                                 tweet sentiment
# 3013  them cold, dark nights are slowly creeping in 🌌  Negative
#
# Emotion: ('anticipation', 'trust')
#                                                   tweet sentiment
# 325   It's #ThirstyThursday which means it's time to...  Positive
# 1739       It's about time I start taking my own advice  Positive
# 3098  That's how you start a season that's how you o...  Positive
#
# Emotion: ('disgust',)
#                                                   tweet sentiment
# 142   Congrats to #Nicole #bb18 ... Fix that nose no...   Neutral
# 143   Congrats to #Nicole #bb18 ... Fix that nose no...   Neutral
# 2182  its been ages since ive had shawarma my stomac...   Neutral
# 2183  its been ages since ive had shawarma my stomac...   Neutral
#
# Emotion: ('disgust', 'anger', 'negative')
#                                                   tweet sentiment
# 11                       @eMilsOnWheels I'm furious 😩😩😩  Negative
# 30    Fast and furious 6 this Monday 10 pm on mbc 2 ...  Negative
# 46    Yal aggravate tf outta me acting lying yal can...  Negative
# 72                             You offend me, @Tansorma  Negative
# 126   Ok but how are the fast &amp; furious movies N...  Negative
# 140   @ColinOccupantz @JasnaBadzak @proremain and th...  Negative
# 205   Pro Tip: Go back to work when your kid reaches...  Negative
# 267                         resentment is rlly my shit.  Negative
# 269   @paulsherard @margarethaynie wow I just realiz...  Negative
# 359   Beyoncé resentment gets me in my feelings ever...  Negative
# 606   @Mysbananen yes hc and we got him very low. I ...  Negative
# 634   I heard Movie Bob was furious about the Skittl...  Negative
# 677   @dreamsandpocky Like, despite all my irritatio...  Negative
# 1985  The #most wasteful day is a #day without #laug...  Negative
# 1986          The #most wasteful day is a #day without   Negative
# 2511  When you burst out crying alone and u realize ...  Negative
# 2546  Finally watched #hungergamesmockingjay2 this m...  Negative
# 2566  eun: im really unhappy with this and i dont li...  Negative
# 2613                                      Im so unhappy  Negative
# 2730  I don't get that my parents literally don't se...  Negative
# 2932  Honestly don't know why I'm so unhappy most of...  Negative
# 2933  Honestly don't know why I'm so unhappy most of...  Negative
# 3021  It's always depressing to sort WordPress plugi...  Negative
# 3023  Their engine runs on fuel called whining :-)\n...  Negative
# 3033  @danhirtle @Bell Another unhappy customer.  #s...  Negative
#
# Emotion: ('disgust', 'anger', 'negative', 'trust')
#                                                   tweet sentiment
# 724   Will I offend you\nif I am truthful but kind\n...  Positive
# 725   Will I offend you\nif I am truthful but kind\n...  Positive
# 2882  After she threw me out I had to sedate her. Wi...  Positive
#
# Emotion: ('disgust', 'negative')
#                                                   tweet sentiment
# 194   #ADP's #ezlabor web portal has to be THE SLOWE...   Neutral
# 213   @laureeenwillam can't cope wi her sour face an...   Neutral
# 246   some of the casuals tweets that Vic has faved ...   Neutral
# 247   some of the casuals tweets that Vic has faved ...   Neutral
# 595   @RussellHartness @Mariners @BlueJays :  Wrongd...   Neutral
# 1419  Gosh #anxiety attacks turning into #Panic atta...   Neutral
# 1630  @value4tax @Hopkins_Alison That part of Queens...   Neutral
# 2154  @Coffeeking12 @jsavite I was injecting a littl...   Neutral
# 2362  Big thanks to Brad Pitt who's trashy ways brou...   Neutral
# 2974  I feel like a burden every day that I waste bu...   Neutral
#
# Emotion: ('disgust', 'negative', 'anticipation')
#                                                   tweet sentiment
# 276   She began to squirm beneath @hcllbent, struggl...   Neutral
# 544   Cuz even the bible talks about the son coming ...   Neutral
# 2800  Is it just me or is this a very weird time for...   Neutral
#
# Emotion: ('disgust', 'negative', 'anticipation', 'sadness')
#                                                   tweet sentiment
# 228   Oh man it's been so long since I've played #ma...  Negative
# 2622  so probably hunger and depression and dissocia...  Negative
#
# Emotion: ('disgust', 'negative', 'fear')
#                                                   tweet sentiment
# 1622  @theurbanologist the tunnels! I shudder to thi...  Negative
#
# Emotion: ('disgust', 'negative', 'fear', 'anticipation')
#                         tweet sentiment
# 1088  So nervous I could puke  Negative
#
# Emotion: ('disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 519   In inter-group relationships, #anger makes peo...  Negative
# 889   there is no shame in fear, what matters is how...  Negative
# 1611  “Winners are not afraid of losing. But losers ...  Negative
# 2554  @thixotropic No. Was so sudden. Hasn't sunk in...  Negative
# 2589  Ok it really just sunk in that I'm seeing the ...  Negative
# 2644       It hasn't sunk in that I'm meeting the twins  Negative
# 2702  Today: Kudos to Jaime Garcia on a fine outing....  Negative
# 2713  @BlackToLive Good - cuz that's what Trump is: ...  Negative
# 2761  God I give you all my pain mess and stress. Ta...  Negative
# 3020  @suddenlyapples This is an on-going affliction...  Negative
# 3028  @AniahROSE I know smh. My heart sunk into my s...  Negative
#
# Emotion: ('disgust', 'negative', 'fear', 'trust')
#                                                   tweet sentiment
# 2542  @MariamVeiszadeh it's getting so close in your...  Positive
#
# Emotion: ('disgust', 'negative', 'sadness')
#                                                   tweet sentiment
# 343   Marcus Rojo is the worst player i have ever se...  Negative
# 989   Panic attacks are the worst. Feeling really si...  Negative
# 990   Panic attacks are the worst. Feeling really si...  Negative
# 1239  My wedding is in two weeks and I'm actually re...  Negative
# 2157  @Lil_PowWow @jweiler0528 More fat = more buoya...  Negative
# 2340  You got some dick recently right, you're happy...  Negative
# 2876       @SizweM01 and it's kinda depressing hey!!! 😑  Negative
# 2923  The snaps/Insta pics I see of the friends I ma...  Negative
# 2970                            @kerophibian depressing  Negative
# 3059         All work and no play makes Jack a dull boy  Negative
# 3113  @childctweets sad people are that sick and bor...  Negative
# 3114  This whole #VanRE + extradition might turn int...  Negative
#
# Emotion: ('disgust', 'positive', 'joy')
#                                                   tweet sentiment
# 2120  - blood and mucus and he chokes and has to swa...  Positive
#
# Emotion: ('disgust', 'positive', 'negative')
#                                                   tweet sentiment
# 2720  this country is going to go to crap no matter ...   Neutral
# 2890  @brawl2099 See your primary care doctor. They ...   Neutral
#
# Emotion: ('disgust', 'positive', 'negative', 'fear', 'anticipation')
#                                                  tweet sentiment
# 871  I stepped into the shower and my spidey senses...  Negative
# 872  I stepped into the shower and my spidey senses...  Negative
#
# Emotion: ('disgust', 'positive', 'negative', 'joy')
#                                                   tweet sentiment
# 2467  While I was walking, a little boy in a red shi...  Positive
#
# Emotion: ('disgust', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 1201  I'm so bored and fat and full and ridiculously...  Negative
# 1202  I'm so bored and fat and full and ridiculously...  Negative
# 2395  #PeopleLikeMeBecause    People are using this ...  Negative
# 2726  This has been the most depressing week full of...  Negative
#
# Emotion: ('disgust', 'positive', 'negative', 'trust')
#                                  tweet sentiment
# 1210  I'm such a shy person oh my lord  Positive
#
# Emotion: ('disgust', 'positive', 'sadness')
#                                                  tweet sentiment
# 803  @News24 #FMF protesters aren't interested in r...  Negative
#
# Emotion: ('fear',)
#                                                   tweet sentiment
# 158   RE: #politicallycorrect #BS   What if I am #of...  Negative
# 277   @LoyalLadyMalfoy &lt;• change them himself. He...  Negative
# 374   I don't ever know how to change the vibe once ...  Negative
# 899   Southampton playing really well here. Youngste...  Negative
# 1101          thank you for finding this @ @afcEnes coy  Negative
# 1270  @jdwmaguire 'They will be a formidable challen...  Negative
# 1471  @indiamarshall_ that's great! It's not easy!\n...  Negative
# 1893  A #smile can mean a thousand words, but it can...  Negative
# 2190  Tiller and breezy should do a collab album. Ra...  Negative
# 2290  @SowerAsh007 Great to hear. If there's one thi...  Negative
# 2431  @andiymouse @jordana_brown @F1ghtCamp I'm sure...  Negative
#
# Emotion: ('fear', 'anticipation')
#                                                   tweet sentiment
# 540   Glad I didn't watch smackdown because I can't ...  Negative
# 541   Glad I didn't watch smackdown because I can't ...  Negative
# 682   I think it's time to change my #irate motif, n...  Negative
# 1562  The #movie Vantage Point makes my palms sweat ...  Negative
# 1597  Why doesn't anybody I know watch penny dreadfu...  Negative
# 1659  @Simon_Barrett I will watch @BlairWitchMovie w...  Negative
# 3071  @Simon_Barrett I will watch @BlairWitchMovie w...  Negative
#
# Emotion: ('fear', 'anticipation', 'trust')
#                                                   tweet sentiment
# 2308  @Babylonian I convinced my mom to watch it. Ki...  Positive
# 2309  @Babylonian I convinced my mom to watch it. Ki...  Positive
#
# Emotion: ('fear', 'sadness')
#                                                   tweet sentiment
# 861   @jaimeotero_ how about saying something like '...  Negative
# 862   @jaimeotero_ how about saying something like '...  Negative
# 2753  @devrajasmine If you change the dark images bo...  Negative
#
# Emotion: ('fear', 'sadness', 'trust')
#                                                   tweet sentiment
# 1196  Bring on my interview at hospital tho 🙈🙈 #nervous  Positive
# 1197          Bring on my interview at hospital tho 🙈🙈   Positive
#
# Emotion: ('joy', 'anger', 'disgust', 'positive', 'negative')
#                                                   tweet sentiment
# 543   LGBTQ media should inform, inspire, entertain ...  Positive
# 2101  There's a certain hilarity in people angry at ...  Positive
#
# Emotion: ('joy', 'anger', 'disgust', 'positive', 'negative', 'anticipation')
#                                                   tweet sentiment
# 90    No one's gonna chill bc fake outrage is fun or...  Positive
# 2669  Fam what seems more fun for a photo booth: bei...  Positive
#
# Emotion: ('joy', 'anger', 'disgust', 'positive', 'negative', 'fear')
#                                                  tweet sentiment
# 599  I either look like a raging bitch, or I'm obno...  Positive
#
# Emotion: ('joy', 'anger', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 53    A guy was raging so hard during a rocket leagu...  Positive
# 130   warning: i am a sensitive, angry, insecure bab...  Positive
# 249   Note to self ~ Stop laughing at things that of...  Positive
# 811   @DaddyION you and that awful music can take a ...  Positive
# 996   I love my mother, but talking about the recent...  Positive
# 1481  The horrible puns for the day have been made. ...  Positive
# 1532  Ask yourself every day: \nam I ruled by fear a...  Positive
# 1824  @amstrado_CPC @ShittySUFanart the single tear ...  Positive
# 2307  Boys of Fall makes me miss cheering on Friday ...  Positive
# 2432  How do adults remain jovial amidst all the bad...  Positive
# 2444  #LethalWeapon A suicidal Vet with PTSD... so F...  Positive
# 2616  hate to see y'all frown but I'd rather see him...  Positive
#
# Emotion: ('joy', 'anger', 'disgust', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 2187  @lizbon @anomalily @gerikkransky Sorry for the...  Positive
# 2836  &amp; like if your unhappy just leave. don't c...  Positive
#
# Emotion: ('joy', 'anger', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1726  @tweetingacct @amandacarpenter @TeamTrump the ...  Positive
#
# Emotion: ('joy', 'anger', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2743  How a dad would feel knowing his daughter is g...  Positive
# 3061  Seeing an old coworker and his wife mourn the ...  Positive
#
# Emotion: ('joy', 'anger', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 1853  Mou is too jovial and trying to impress those ...  Positive
# 3104  Feminists should ask themselves, why they're s...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'anticipation', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 361   @jbanks88 offense can't score 3 redzone trips ...  Positive
# 756                Will BYU's offense score 24+ vs WVU?  Positive
# 2108  @OccasionalGod isn't that the reason horror is...  Positive
# 2255  Incredible that Nawaz Sharif said Pakistan is ...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 480   My cat is bloody lucky the RSPCA weren't open ...  Positive
# 1757  Bridget Jones' Baby was bloody hilarious 😅 #Br...  Positive
# 2147  I really hate Mel and Sue. They think they're ...  Positive
# 2384  @SomeonesAnIdiot @Sean10Lynagh  due to hearty ...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'disgust', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 272   Height of irritation when a person makes a hil...  Positive
# 275                   jelly baby is my favourite insult  Positive
# 2288  @PixelMonsterYT @TeamGE0 @IZEDEPTIC @ztumtum @...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'negative', 'anticipation')
#                                                   tweet sentiment
# 1905  Every time I hear @jtkantor's organ kick in on...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1194  @1StevieKilner @KachelaMurray Don't be silly -...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'positive', 'negative', 'anticipation')
#                                                  tweet sentiment
# 493  @RadiateZen That's true, it does go both ways....  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 1286  😂 - youre one of those whod bully me omg but i...  Positive
#
# Emotion: ('joy', 'anger', 'surprise', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1108  A goal should scare you a little, and excite y...  Positive
#
# Emotion: ('joy', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2919  Special thanks to @hamsterwatch &amp; @UgotBro...  Positive
#
# Emotion: ('joy', 'positive', 'anticipation')
#                                                   tweet sentiment
# 241   Nothing more entertaining and frightening than...  Positive
# 938   Why is it so windy? So glad I didn't ride my b...  Positive
# 939   Why is it so windy? So glad I didn't ride my b...  Positive
# 1092  If you think reason will prevail in this elect...  Positive
# 1093  If you think reason will prevail in this elect...  Positive
# 1235  On the last episode of #MakingAMurderer poor B...  Positive
# 1236  On the last episode of #MakingAMurderer poor B...  Positive
# 1257  If u know anything about football help me out ...  Positive
# 1315  @NigeriainfoFM #start football league, I think...  Positive
# 1804  We so elated, we celebrated like Obama waited ...  Positive
# 1850      🎉 It is time for a most joyous celebration! 🎉  Positive
# 1870  @Bhavnay that, i dont mind too much. smoother,...  Positive
# 1920  @xiankiefer @TheLincoln Book 5! It's so sprigh...  Positive
# 1921  How's it possible to go from cheery earlier to...  Positive
# 1929  wanna always be the reason behind her happines...  Positive
# 1980  @RayGemini I've got 8 coming back this week. I...  Positive
# 2049  Happy #internationaldayofpeace everyone hoping...  Positive
# 2097                      Miss my lil caramel delight 💓  Positive
 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2504  My nephews n cousins are nowhere near bad guys...  Positive
# 2505  My nephews n cousins are nowhere near bad guys...  Positive
#
# Emotion: ('trust', 'anger', 'anticipation', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                  tweet sentiment
# 813  @AdoreDelano ill be there... with VIP TICKETS!...  Positive
# 814  @AdoreDelano ill be there... with VIP TICKETS!...  Positive
#
# Emotion: ('trust', 'anger', 'anticipation', 'disgust', 'positive', 'negative', 'sadness')
#                                                  tweet sentiment
# 191  My irritation level is at an all time high tod...  Positive
#
# Emotion: ('trust', 'anger', 'anticipation', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2795  A pessimist sees the difficulty in every oppor...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'negative', 'fear')
#                                                   tweet sentiment
# 505   @Kruzer You're not stealing my girl, I've solo...  Positive
# 1022  Stoked that the concept of 'label exclusivity'...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 184   @JohnJHarwood @GWGMJ30 It's no secret: persona...  Positive
# 703   @RelUnrelated While I do not see Sailer Mars b...  Positive
# 1117  Love all the ex United managers on Twitter who...  Positive
# 1167  with terrorism a booming industry in Pak and g...  Positive
# 1618  The whole idea f a nation revolves around Kash...  Positive
# 1885  @Get_Quenched16 Attempts by Western degenerate...  Positive
# 2481  @MHChat sadness with resentment is the past, s...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'positive', 'negative')
#                                                  tweet sentiment
# 70   @NahteWilly @AFP that was neither intelligent,...  Positive
# 171  @MegMuphet I wasn't meaning to offend you. I w...  Positive
# 459  @Iucifaer you can go on what you usually do it...  Positive
# 580  Undifferentiated otherwise patent closest patr...  Positive
# 729  @HuffingtonPost huff i know your pro-hillary a...  Positive
# 730  @Christelle_C Actually, wait, I do, the consta...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 2866  @WalshFreedom sadly, that idiot completely ove...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1188  @BuzzFeedAndrew @MattMurph24 start a countdown...  Positive
# 1356  @sethwieck you should do a TED Talk on 'bubled...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 13    They gonna give this KKk police bitch the mini...  Positive
# 14    They gonna give this KKk police bitch the mini...  Positive
# 182   @daemondave @paulkrugman Hey stupid, that was ...  Positive
# 320   I told myself i wouldn't talk about this but i...  Positive
# 383   Its worth noting that despite the animosity be...  Positive
# 425   @ScottCarmichae1 @Murican_Stuff don't fret -- ...  Positive
# 775   @JamesPiotr I am working on a feature right no...  Positive
# 828   @AliKhanSays Oh come on. RAW and ISI have been...  Positive
# 959   @tariqmateen but sadly he missed some crucial ...  Positive
# 1544  But this is the internet age, so get mad out o...  Positive
# 1705  SO many great pics from the show in Tokyo😍 I l...  Positive
# 2660  @rosalarian i hate post con blues! But i avoid...  Positive
# 2831  @ScottCarmichae1 @Murican_Stuff don't fret -- ...  Positive
# 2873  People are trying too hard to hate on Cam Newt...  Positive
# 2874  People are trying too hard to hate on Cam Newt...  Positive
# 2924  @tariqmateen but sadly he missed some crucial ...  Positive
#
# Emotion: ('trust', 'anger', 'disgust', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 155   Trump supports reach another level of irritati...  Positive
# 691   @jackmegawphoto what if lives are attached to ...  Positive
# 2461  To tell the truth and make someone cry is bett...  Positive
# 2462  To tell the truth and make someone cry is bett...  Positive
# 2521  Urgent need to get a new job. The constant glo...  Positive
# 2975  @RIPPoohSavage u know ion play that shit bout ...  Positive
# 3127  @flybe Doesn't explain the ability to land at ...  Positive
#
# Emotion: ('trust', 'anger', 'negative', 'fear', 'sadness')
#                                                  tweet sentiment
# 24   @SportingTommo @ASFCofficial no doubt we are g...  Positive
# 416  @EASPORTS_MUT fix this home/away deptch chart ...  Positive
#
# Emotion: ('trust', 'anger', 'positive', 'negative', 'anticipation')
#                                                   tweet sentiment
# 894   I forgot #BB18 was on tonight  that is how mu...  Positive
# 972   @ShannonBeador we know the truth about her, th...  Positive
# 1392  @ShannonBeador we know the truth about her, th...  Positive
# 1393  I forgot #BB18 was on tonight 😳 that is how mu...  Positive
# 2609  @ShannonBeador we know the truth about her, th...  Positive
#
# Emotion: ('trust', 'anger', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 295   Everything I see of American police training s...  Positive
# 823    The terror threat level really need to be raised  Positive
# 1071  When you get to a point as an officer that you...  Positive
# 1240  Virtually every statement by other countries a...  Positive
# 1533  This brother know we know that his life was no...  Positive
# 1623  @MSNBC @fox @cnn @realDonaldTrump @HillaryClin...  Positive
# 2809  Too many are on their 'yeah, the thing going o...  Positive
# 2810  Too many are on their 'yeah, the thing going o...  Positive
#
# Emotion: ('trust', 'anger', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 919   It's unbelievable that security guard acting l...  Positive
# 1268  @wittyneeraj What is Shehla Rashid &amp; Kaniy...  Positive
# 1391  If a cop is going to pull a gun on you for no ...  Positive
#
# Emotion: ('trust', 'anger', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 518   Why are people even debating on race inequalit...  Positive
# 2477  BTW, offended policy wonks, H only had one rea...  Positive
#
# Emotion: ('trust', 'anger', 'positive', 'negative', 'sadness')
#                                                  tweet sentiment
# 714  But if you wish to live bitter because your gu...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'disgust', 'negative', 'fear')
#                                                   tweet sentiment
# 1130  Whenever you are confronted by a wild animal o...  Positive
# 1344  @ClaretNBlues forest gate u could see he was a...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'disgust', 'positive', 'negative', 'anticipation')
#                                                  tweet sentiment
# 252  Do not be angry with God because you do not ge...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 433   @JoyAnnReid you're right choice I had to slam ...  Positive
# 670   @TheJuanWilliams Where is your indignation and...  Positive
# 1354  @ryleycathryn @Mack_Shepp did you discover the...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'disgust', 'positive', 'negative', 'sadness')
#                                                  tweet sentiment
# 336  @itgoeszaysway ok but his identity was reveale...  Positive
# 346  @majesticmata didn't even realise you used tha...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'negative', 'fear', 'anticipation')
#                                                  tweet sentiment
# 439  @VeyGraphics I had to unfollow, he got trolled...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'positive', 'negative', 'anticipation')
#                                                   tweet sentiment
# 1667  Buying an early entry tickets at @EGX means fu...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 1444  And they cover these police shootings fairly w...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'positive', 'negative', 'fear', 'anticipation')
#                                                  tweet sentiment
# 172  @SINice Damn..  Lol..  Maybe it is for the bes...  Positive
#
# Emotion: ('trust', 'anger', 'surprise', 'positive', 'negative', 'fear', 'sadness')
#                                                 tweet sentiment
# 43  @aGirlHasNo_Name @MdlMurray shot by black poli...  Positive
#
# Emotion: ('trust', 'anticipation', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2688  I wonder if the #wolfcreek TV show is sponsore...  Positive
#
# Emotion: ('trust', 'anticipation', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2752  @MHChat if we don't understand how to express ...  Positive
#
# Emotion: ('trust', 'disgust', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2515  What's the worst affliction that you or someon...  Positive
#
# Emotion: ('trust', 'disgust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 2552  @MlaStandard The depth that you've sunk to. Yo...  Positive
# 2694  Don King...his actions really sadden me today....  Positive
#
# Emotion: ('trust', 'disgust', 'positive', 'negative', 'sadness')
#                                                   tweet sentiment
# 2888  someone explain female human beings to me, the...  Positive
#
# Emotion: ('trust', 'positive', 'anticipation', 'sadness')
#                                                   tweet sentiment
# 2894  Lines from Don't Quit take me to a place of ul...  Positive
#
# Emotion: ('trust', 'positive', 'anticipation', 'surprise')
#                                                   tweet sentiment
# 2475  @British_Airways In your Concorde Lounge in Te...  Positive
#
# Emotion: ('trust', 'positive', 'joy', 'sadness')
#                                                   tweet sentiment
# 1811  I'm at the point in my life that I'm playing C...  Positive
#
# Emotion: ('trust', 'positive', 'joy', 'surprise')
#                                                   tweet sentiment
# 1806  I just want to let everyone out there know you...  Positive
# 1807  I just want to let everyone out there know you...  Positive
# 1828                  I'm the reason I smile everyday 💯  Positive
# 1984  @Harry_Styles you're the smile to my face and ...  Positive
# 1995  How wonderful to see a show with a token man f...  Positive
# 2306  you know it's beauty when the smile is her bes...  Positive
# 2446  I don't fuck with people who don't smile back ...  Positive
#
# Emotion: ('trust', 'positive', 'negative', 'fear', 'anticipation')
#                                                   tweet sentiment
# 1360  me: loves being the center of attention in eve...  Positive
# 1406  Embarrassing lack of defensive depth coming ba...  Positive
#
# Emotion: ('trust', 'positive', 'negative', 'fear', 'sadness')
#                                                   tweet sentiment
# 300   @mikeburke91 @AP I guess. It's just heartbreak...  Positive
# 301   @mikeburke91 @AP I guess. It's just heartbreak...  Positive
# 1524  They want as police state, they are fearful im...  Positive
# 2584  #HRmanagement must discourage the expediency f...  Positive
# 2708  @ChristianJMay @CityAM \nConfidence held up......  Positive
# 2803  For once I gatherp th strength to not try and ...  Positive
# 3115  @MarkedMurderer Orion's eyes narrowed as he ga...  Positive
#
# Emotion: ('trust', 'surprise', 'disgust', 'negative', 'fear')
#                                                   tweet sentiment
# 1149  the day they disclosed they caught her googlin...  Positive
#
# Emotion: ('trust', 'surprise', 'positive', 'negative', 'anticipation')
#                                                   tweet sentiment
# 2567  @yesnicksearcy @counterparty Although I don't ...  Positive
# 2568  @yesnicksearcy @counterparty Although I don't ...  Positive
#
# Emotion: ('trust', 'surprise', 'positive', 'negative', 'fear')
#                                                   tweet sentiment
# 1166  This girl was shaking her drink in the break r...  Positive
#
# Emotion: ('trust', 'surprise', 'positive', 'negative', 'fear', 'anticipation')
#                                                  tweet sentiment
# 817  In honor of Shawty Lo passing away I made Dey ...  Positive

# %%
def map_emotions_to_sentiment(emotions):
    if 'anger' in emotions or 'sadness' in emotions:
        return 'Negative'
    elif 'fear' in emotions:
        return 'Neutral'
    elif 'joy' in emotions:
        return 'Positive'
    else:
        return 'Unknown'

all_test_data['actual_sentiment'] = all_test_data['Emotion'].apply(map_emotions_to_sentiment)

# %%
emotion_groups.head()
# Out:
#       index                                              tweet  Emotion  \
# 0     10941  At the point today where if someone says somet...    anger
# 1     10942  @CorningFootball  IT'S GAME DAY!!!!      T MIN...    anger
# 2     10943  This game has pissed me off more than any othe...    anger
# 3     10944  @spamvicious I've just found out it's Candice ...    anger
# 4     10945  @moocowward @mrsajhargreaves @Melly77 @GaryBar...    anger
# ...     ...                                                ...      ...
# 3112  41503  On the wheel as we grow older and become aware...  sadness
# 3121  41512  @ExaltedChampion - the jest, Kara didn't chuck...  sadness
# 3134  41525  Nutella is pine green forget me nots are ivory...  sadness
# 3140  41531  I'm buying art supplies and I'm debating how s...  sadness
# 3141  41532  @sainsburys Could you ask your Chafford Hundre...  sadness
#
#       vader_score                                           emotions  \
# 0          0.5267                             [positive, joy, trust]
# 1          0.0000                                                 []
# 2         -0.6988                                                 []
# 3          0.4215                             [positive, joy, trust]
# 4          0.0000                                                 []
# ...           ...                                                ...
# 3112      -0.4019  [joy, trust, anticipation, positive, negative,...
# 3121      -0.2865           [joy, positive, negative, fear, sadness]
# 3134       0.0516  [joy, trust, anticipation, positive, negative,...
# 3140      -0.0772   [sadness, joy, surprise, positive, anticipation]
# 3141      -0.1511                  [positive, anticipation, sadness]
#
#                                          emotions_tuple sentiment  \
# 0                                (positive, joy, trust)  Positive
# 1                                                    ()   Neutral
# 2                                                    ()   Neutral
# 3                                (positive, joy, trust)  Positive
# 4                                                    ()   Neutral
# ...                                                 ...       ...
# 3112  (joy, trust, anticipation, positive, negative,...  Positive
# 3121           (joy, positive, negative, fear, sadness)  Positive
# 3134  (joy, trust, anticipation, positive, negative,...  Positive
# 3140   (sadness, joy, surprise, positive, anticipation)  Positive
# 3141                  (positive, anticipation, sadness)  Negative
#
#      actual_sentiment
# 0            Negative
# 1            Negative
# 2            Negative
# 3            Negative
# 4            Negative
# ...               ...
# 3112         Negative
# 3121         Negative
# 3134         Negative
# 3140         Negative
# 3141         Negative
#
# [922 rows x 8 columns]

# %%
accuracy = (all_test_data['sentiment'] == all_test_data['actual_sentiment']).mean()
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.42329726288987907

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(all_test_data['actual_sentiment'], all_test_data['sentiment'])
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[516 504 413]
#  [330 405 260]
#  [ 51 254 409]]

# %%
from sklearn.metrics import classification_report

class_report = classification_report(all_test_data['actual_sentiment'], all_test_data['sentiment'])
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.58      0.36      0.44      1433
#      Neutral       0.35      0.41      0.38       995
#     Positive       0.38      0.57      0.46       714
#
#     accuracy                           0.42      3142
#    macro avg       0.43      0.45      0.42      3142
# weighted avg       0.46      0.42      0.42      3142

# %%
import matplotlib.pyplot as plt

sentiment_counts = all_test_data['sentiment'].value_counts()
sentiment_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Distribution of Predicted Sentiments')
plt.show()

# %%
for sentiment, group in all_test_data.groupby('sentiment'):
    print(f"Sentiment: {sentiment}")
    for i, row in group.sample(min(5, len(group))).iterrows():
        print(row['tweet'])
    print()
# Out:
# Sentiment: Negative
# Last night I had a dream that today was Christmas. I woke up screaming because I wasn't ready.
# @omgitsbrittanyy @WittLowry u probably irritate the shit out of him always talking to him. He could probably give 2 shits about u lol 🖕🏻
# @jamiesmart Huh! It's always my fault isn't it &gt;:( #huff #sulk
# @MatherFamilys @SDICenter @CAllstadt \n\ndo REDNECKS intellectually intimidate you and force you to be their dancing clown?
# @RealTimBooth I've never been fond of having dark eyes until seeing this share.
#
# Sentiment: Neutral
# Tho we haven't talked Jeff but the news is so sad and shocking. R.I.P Jeffrey
# @TheCatCampbell I too am Ravenclaw. #sadness #shouldhavebeenhufflepuff
# @stephtikkanen oh so true, so true.
# @kcbbcxo don't get discouraged! it's early on &amp; it can get overwhelming. keep reading &amp; use cue cards 😊 it'll get better!!
# Everyday I wake up, a different @SpursOfficial player signs a contract extension! Love it!! #future #is #bright #COYS
#
# Sentiment: Positive
# Wow... One of my dads top favorite throwback rappers just died in a fiery car crash today in Atlanta, so sad so sad 😷😷
# @RiveraJose39 happy birthday to my seed‼️‼️‼️ #renewtherivalry #imyourdaddy #cantbeatme #madden #tater
# @WelshGasDoc @PlaidCymru supporter @reesmarshall239 #prejudice against #disabled people #disabledlivesmatter #bully #bbcnews #skynews
# @Harry_Styles 💖\nHeart so pure and smile\nso bright, I love you\nmore than the number\nof stars at night.\nKindly follow me please\nHarry?\n—90,127
# Fam what seems more fun for a photo booth: being able to instantly post to Twitter or having to wait till sober to see the hot mess

# %%
for sentiment, group in all_test_data.groupby('sentiment'):
    print(f"Sentiment: {sentiment}")
    emotion_counts = group['emotions'].explode().value_counts()
    print(emotion_counts)
    print()
# Out:
# Sentiment: Negative
# negative        853
# fear            601
# sadness         561
# anger           551
# disgust         361
# anticipation    198
# positive        151
# surprise        118
# Name: emotions, dtype: int64
#
# Sentiment: Neutral
# positive        157
# anticipation    100
# negative         93
# surprise         23
# disgust          19
# Name: emotions, dtype: int64
#
# Sentiment: Positive
# positive        977
# joy             809
# trust           786
# anticipation    559
# negative        504
# surprise        378
# sadness         347
# fear            332
# anger           329
# disgust         223
# Name: emotions, dtype: int64
